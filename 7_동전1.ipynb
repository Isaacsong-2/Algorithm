# %%
n, k = map(int, input().split())
coin = []
for i in range(n):
  coin.append(int(input()))
# Out:
# 3 10
# 2
# 5
# 1

# %%
coin.sort()
sol = [1] + [0]*k
for i in coin:
  for j in range(i, k+1):
    if j - i >= 0:
      sol[j] += sol[j-i]
print(sol[k])
# Out:
# 10
