# %%
n, m, k = map(int, input().split())
# Out:
# 5 20 4
# 5 20 4

# %%
rail = list(map(int, input().split()))
# Out:
# 5 8 10 19 7

# %%
def sol():
  for i in range(n):
    if rail[i] < m:
      sum += 1
# Out:
# [5, 8, 10, 19, 7]
