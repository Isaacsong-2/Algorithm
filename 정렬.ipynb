# %%
a = [0, 131, 122, 140, 34, 148, 129.5, 133.5, 92, 144, 100, 98.5, 76.5, 124, 110, 114, 81.5, 154.5, 70.5, 56, 141, 90.5, 130.5, 159.5, 113, 157.5, 114.5, 129.5, 150.5, 69.5, 129, 128.5, 108.5, 122, 109, 139]
a.sort()
for i in range(len(a)):
  a[i] *= 0.3
  a[i] = round(a[i], 1)
print(a)
# Out:
# [0.0, 10.2, 16.8, 20.8, 21.1, 22.9, 24.4, 27.1, 27.6, 29.5, 30.0, 32.5, 32.7, 33.0, 33.9, 34.2, 34.4, 36.6, 36.6, 37.2, 38.5, 38.7, 38.9, 38.9, 39.1, 39.3, 40.0, 41.7, 42.0, 42.3, 43.2, 44.4, 45.1, 46.4, 47.2, 47.9]
