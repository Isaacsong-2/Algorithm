# %%
n = int(input())
a = list(map(int, input().split()))
# Out:
# 10
# 2 1 -4 3 4 -4 6 5 -5 1

# %%
sol = [0] * n
k = -1001
for i in range(n):
  sol[i] = max(sol[i-1] + a[i], a[i])
  k = max(k, sol[i])
print(k)
# Out:
# 2
