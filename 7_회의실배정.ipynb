# %%
n = int(input())
arr = []
for i in range(n):
    start, end = map(int, input().split())
    arr.append([start, end])

arr = sorted(arr, key=lambda a: a[0])
arr = sorted(arr, key=lambda a: a[1])

t = 0
cnt = 0
for i, j in arr:
    if i >= t:
        cnt += 1
        t = j
print(cnt)
# Out:
# 3
# 1 4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a3a35c7b5b90> in <module>()
#       3 for i in range(n):
#       4     start, end = map(int, input().split())
# ----> 5     s.append([start, end])
#       6
#       7 arr = sorted(arr, key=lambda a: a[0])
#
# NameError: name 's' is not defined
