# %%
def solution(game_board, table):
    rc = len(game_board)
    #print(rc)
    visit = [[0]*rc for _ in range(rc)]
    #print (visit)
    dx = [0, 0, -1, 1]
    dy = [1, -1, 0, 0]
    for i in range(rc):
        for j in range(rc):
            if game_board[i][j] == 0 and visit[i][j] == 0:
                dfs = [[i, j]]
                for k in range(4):
                    
    answer = -1
    return answer
