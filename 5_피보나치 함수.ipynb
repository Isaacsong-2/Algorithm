# %%
import sys
input = sys.stdin.readline
t = int(input())
def sol0(a):
  i = 0
  if a == 0:
    return 1
  if a == 1:
    return 0
  return(sol0(a-1) + sol0(a-2))

def sol1(a):
  i = 0
  if a == 1:
    return 1
  if a == 0:
    return 0
  return(sol1(a-1) + sol1(a-2))

for _ in range(t):
  a = int(input())
  print(sol0(a), " ", sol1(a))
# Out:
# 3
# 0
# 1   0
# 1
# 0   1
# 3
# 1   2

# %%
n = int(input())
arr = list(int(input()) for i in range(n))

res_arr = [[1,0], [0,1]]

for i in range(2,max(arr)+1):
  res_arr.append([res_arr[i-1][0] + res_arr[i-2][0], res_arr[i-1][1] + res_arr[i-2][1]])
  print(res_arr[i][0], res_arr[i][1])
#for num in arr:
#  print(res_arr[num][0], res_arr[num][1])
# Out:
# 3
# 0
# 1
# 3
# 1 1
# 1 2

# %%
t = int(input())
for _ in range(t):
  s = [0, 1]
  a = int(input())
  for i in range(2, a+1):
    s.append(s[i-1] + s[i-2])
  print(s[a-1], s[a])
# Out:
# 3
# 0
# 1  0
# 1
# 0  1
# 3
# 1  2
