# %%
n = int(input())
s = [0, 0, 1, 1]
for i in range(4, n+1):
  s.append(s[i-1]+1)
  if i%3 == 0:
    s[i] = min(s[i], s[i//3]+1)
  if i%2 == 0:
    s[i] = min(s[i], s[i//2]+1)
print(s[n])
# Out:
# 10
# 3
