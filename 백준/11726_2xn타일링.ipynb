# %%
'''
1 - 1
2 - 2
3 - 3
4 - 5	1+3+1
5 - 8	1+4+3
6 - 13	1+5+6+1
7 - 21	1+6+10+4
'''
n = int(input())
sol = []
sol.append(1)
sol.append(2)
for i in range(2, n):
  sol.append(sol[i-1]+sol[i-2])

print(sol[n-1]%10007)
# Out:
# 9
# 55
