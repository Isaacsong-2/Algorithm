# %%
n = int(input())
a = list(map(int, input().split()))
print(n)
print(a)
# Out:
# 10
# [1, 5, 8, 6, 7, 8, 2, 3, 4, 5]

# %%
dp = [1] * n

for i in range(n):
    for j in range(i):
        if a[i] > a[j]:
            dp[i] = max(dp[i], dp[j]+1)
print(max(dp))
# Out:
# 5
