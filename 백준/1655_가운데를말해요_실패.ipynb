# %%
# n = int(input())
# num = [10001] * 100000
# for i in range(n):
#   a = int(input())
#   for j in range(i+1):
#     if num[j] > a:
#       num.insert(j, a)
#       break
#   b = num[i//2]
#   print2
# (b)
import heapq
n = int(input())
arr_l = []
arr_r = []
for i in range(n-1):
  num = int(input())
  if len(arr_l) == len(arr_r):
    if arr_r[0] < num:
      heapq.heappush(arr_r, num)
      heapq.heappush(arr_l, heapq.heappop(arr_r))
    else:
      heapq.heappush(arr_l, num)
  else:
    if arr_r[0] < num:
      heapq.heappush(arr_r, num)
    else:
      heapq.heappush(arr_l, num)
  print(arr_l, i, arr_r)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14384/3715067441.py in <module>
#      22       heapq.heappush(arr_l, num)
#      23   else:
# ---> 24     if arr_r[0] < num:
#      25       heapq.heappush(arr_r, num)
#      26     else:
#
# IndexError: list index out of range
