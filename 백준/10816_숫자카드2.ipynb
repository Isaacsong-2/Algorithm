# %%
N = int(input())
a = list(map(int, input().split()))
M = int(input())
b = list(map(int, input().split()))
count = [0]*20000001

# %%
for i in range(N):
  count[a[i]] += 1
for i in range(M):
  print(count[b[i]], end = ' ')
# Out:
# 6 0 0 2 4 0 0 4
