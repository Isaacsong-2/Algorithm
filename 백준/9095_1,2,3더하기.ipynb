# %%
T = int(input())
def ans(a):
  if a==1:
    return 1
  elif a==2:
    return 2
  elif a==3:
    return 4

  else:
    return (ans(a-1) + ans(a-2) + ans(a-3))
for i in range(T):
  a = int(input())
  print(ans(a))
# Out:
# 3
# 7
# 324
# 4
# 12
# 10
# 8748
