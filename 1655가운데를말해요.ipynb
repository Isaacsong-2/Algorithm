# %%
n = int(input())
num = [10001] * 100000
for i in range(n):
  a = int(input())
  for j in range(i+1):
    if num[j] > a:
      num.insert(j, a)
      break
  b = num[i//2]
  print(b)
# Out:
# 7
# 1
# 1
# 5
# 1
# 2
# 2
# 10
# 2
# -99
# 2
# 7
# 2
# 5
# 5
