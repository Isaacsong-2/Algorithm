# %%
from collections import deque
T = int(input())
for i in range(T):
  N, M = list(map(int, input().split()))
  M2 = M
  #NM = list(input().split() for i in range(2))
  a = list(map(int,input().split()))
  cnt = 0
  for i in range(N):
    if a[M] < a[i]:
      cnt += 1
    elif a[M] == a[i]:
      if M > i:
  print(cnt)
# Out:
# 3
# 1 0
# 5
# 1
# 4 2
# 1 2 3 4
# 2
# 6 0
# 1 1 9 1 1 1
# 6
