# %%
n = int(input())
a = int(input().split())
# Out:
# 6
# 10 20 10 30 20 50
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-6decccc3b939> in <module>()
#       1 n = int(input())
# ----> 2 a = int(input()).split()
#
# ValueError: invalid literal for int() with base 10: '10 20 10 30 20 50'
